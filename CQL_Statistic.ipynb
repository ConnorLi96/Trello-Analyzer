# %%
import urllib.request
import re
import sys
import codecs
import json
from datetime import datetime
import os
import glob
import utils
import time
import getopt
import ssl
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei']#设置字体以便支持中文
plt.rcParams['savefig.dpi'] = 300 #图片像素
plt.rcParams['figure.dpi'] = 300 #分辨率
plt.rcParams['axes.unicode_minus']=False  #set for displaying `-

# %%
# 设置参数

g_token = "c68bb70c102d863b3d96bc5b8901ff7689dfcba68f040b4fb3d56e9b2f8dbab8"
g_app_key = "e70d4c831ca1c79442f7ef7a68aeb9e3"
g_user_id = "5c16ff1d6e249c62d057987f"
g_board_id = "5ac3159ed146b0793ff30206" # ThunderDB
# g_board_id = "5b640e00c8b518181d80fa46" # Rating system
g_crontab_style = False

workload_pattern = u'[(（]\s*(\d+(?:\.\d+)?)\s*(pt|PT|pT|Pt)\s*[)）]' # 正则表达式
requirement_pattern = u'[\[【［]\s*(.*)\s*[】］\]]\s*'

# %%
def basic_replace(url): # 替换 url 等主要参数
    url = url.replace("_APP_KEY_", g_app_key)
    url = url.replace("_TOKEN_", g_token)
    return url

def do_request(url): 
    context = ssl._create_unverified_context()
    request = urllib.request.Request(url) # urllib 网页抓取的库
    content = None
    flag = False

    for i in range(3):  # retry when network access failed 等于说这里是尝试了三遍
        try:
            response = urllib.request.urlopen(request, context= context) # 会验证一次 SSL 证书, 当目标使用的是自签名的证书时就会报 SSL 错误
            content = response.read().decode()
            flag = True # flag 应该是用来判断 try 是否执行成功
            break
        except urllib.request.HTTPError as e: # 给出报错信息
            print("http error: " + str(e))
        except Exception as e:
            print("error: " + str(e))

    if not flag:
        sys.exit(-1) # 没有 flag 说明报错了，然后退出程序

    if content is None:
        return []
    else:
        return json.loads(content)

# %%
def get_card_name_by_pattern(card_name, pattern):
    return re.findall(pattern, card_name, re.S | re.U) # 搜索字符串，以列表类型返回全部能匹配的子串

def fetch_board_by_user():
    url = 'https://api.trello.com/1/members/_USERID_/boards?key=_APP_KEY_&token=_TOKEN_'
    url = basic_replace(url)
    url = url.replace("_USERID_", g_user_id)
    body = do_request(url)
    board_info = {}

    for item in body:
        board_info[item['shortLink']] = item['name']

    return board_info # 拿到 board 的 name 和 shortlink 意味着可以放进 url 直接访问页面

def insertStr(str_name): 
    
    if "[" in str_name: # 沙雕了。。。“[]”是意味着两个连在一起的
        str_list = list(str_name) # 字符数，可以利用这个在某个位置插入字
        str_pos = str_list.index('[') # 找到[ 的位置
        str_list.insert(str_pos, '\\') # 插入要插入的字符
        str_2 = "".join(str_list) # 将 list 转为 str
    
    else:
        str_2 = str_name
    
    return str_2

def get_card_name_by_pattern(card_name, pattern):
    return re.findall(pattern, card_name, re.S | re.U)

def fetch_list_id_by_board(list_pattern): # list_pattern 作为参数要输入 list name 
    url = 'https://api.trello.com/1/boards/_BOARDID_/lists?key=_APP_KEY_&token=_TOKEN_'
    url = basic_replace(url)
    url = url.replace("_BOARDID_", g_board_id)
    body = do_request(url) # 返回那个 board 里所有的 list 信息
    list_info = []
    list_name = insertStr(list_pattern) # 识别 "[]" 
    
    for item in body:
        
        if re.search(list_name, item["name"], re.I) is not None: # re.search 在一个字符串中搜索匹配正则表达式的第一个位置，返回match对象
            list_info.append({'id': item['id'], 'name': item['name']}) 
            

    return list_info # 返回 list name 和 list_id

def fetch_members_by_board(): # 拿到所有成员的名称和 id
    url = 'https://api.trello.com/1/boards/_BOARDID_/members?key=_APP_KEY_&token=_TOKEN_'
    url = basic_replace(url)
    url = url.replace("_BOARDID_", g_board_id)
    body = do_request(url)
    all_members_info = {}

    for item in body:
        all_members_info[item['id']] = item['fullName']

    return all_members_info # 返回 id 和 member name

def fetch_cards_by_list_id(list_id): #  可以通过上面的 fetch_list_id_by_board 可以获取 list_id
    url = 'https://api.trello.com/1/lists/_LISTID_/cards?key=_APP_KEY_&token=_TOKEN_'
    url = basic_replace(url)
    url = url.replace("_LISTID_", list_id) 
    body = do_request(url)

    return body # 用 list_id 获取 cards 的所有信息

# %%
def get_cards_info(list_id, board_members):

    available_cards_info = []
    all_cards_info = fetch_cards_by_list_id(list_id)

    #   项目名称 项目种类 负责人 项目耗时 项目周 描述

    for item in all_cards_info:
        card_info = { # 设置很多空的 dict，然后依据后面的判断填入一些参数
            'card_type': None,
            'card_name': item['name'],
            'card_id': item['id'],
            'member_id': None,
            'member_name': None,
            'plan_hours': 0,
            'actual_hours': 0, # 现在好像没有分 actual hours 和 plan 
            "description" : item["desc"]
        }

        
        if len(item["name"].split("【")) > 1:
            card_info["card_type"] = item["name"].split("【")[1].split("】")[0]
            
            
        idMembers = item['idMembers'] # 让 cards_info get 到 member 的信息
        if len(idMembers) > 0 and idMembers[0] is not None:
            member_id = idMembers[0]
            card_info['member_id'] = member_id
            card_info['member_name'] = board_members[member_id] # 这里不是报错是和 fetch_members_by_board 一起获得

        labels = item['labels']

        if len(labels) > 0 and labels[0] is not None: # 处理卡片的 labels
            label = labels[0]
            card_info['label_id'] = label['id']
            card_info['label_name'] = label['name']

        card_hours = get_card_name_by_pattern(item['name'], workload_pattern)

        if len(card_hours) == 2:
            card_info['actual_hours'] = float(card_hours[1][0]) * 2
            card_info['plan_hours'] = float(card_hours[0][0]) * 2
        else:
            card_info['actual_hours'] = float(card_hours[0][0]) * 2


        available_cards_info.append(card_info)

    return available_cards_info

# %%
def period_list(list_name): # 通过输入单个的 list_name，然后统计从那个时候到现在的个人工作时间
    list_id = fetch_list_id_by_board(list_name)
    id_list = []
    url = 'https://api.trello.com/1/boards/_BOARDID_/lists?key=_APP_KEY_&token=_TOKEN_'
    url = basic_replace(url)
    url = url.replace("_BOARDID_", g_board_id)
    body = do_request(url)
    
    for i in body:
        id_list.append(i["id"])
        
    for item in body: # 这里没有 item 的异常处理
        if item["id"] == list_id[0]["id"]: 
            id_pos = id_list.index(item["id"]) # 写漏了 id_list 从哪儿来

    return id_list[3:id_pos+1]

# %%
period_list("Done[20190215]")
# Out:
# ['5d06eef0b6e95e05d8bea068',
#  '5cfdb2a0d4ebe10c61bf15b7',
#  '5cf3d8f30b906c18a1591a98',
#  '5cec905c56e9c039cc879a01',
#  '5ce1f23a7103e93bbfb5fa02',
#  '5cd8c0cba986e325375046ba',
#  '5cce46a2384b4b3dcbb12531',
#  '5cc652288dda046d54b00cbc',
#  '5cbc75920f2ce20a9e39fed8',
#  '5cb482db77cdf785b9b4777f',
#  '5caa070d0f951d86f68f67b4',
#  '5ca0c84744259a35c842e3b3',
#  '5c983270b11ed084aa19d1d0',
#  '5c8f0efb6245917192960b79',
#  '5c85bed81d73ea51b24bc340',
#  '5c7c7973876d6309b53d5c76',
#  '5c73a25bb856025094b60989',
#  '5c6a1792e64bec80de03adf8',
#  '5c605b17a623733945ae9498']

# %%
get_cards_info("5ce1f23a7103e93bbfb5fa02", board_members)
# available_cards_info = []
# all_cards_info = fetch_cards_by_list_id("5ce1f23a7103e93bbfb5fa02")
# Out:
# [{'card_type': '招聘',
#   'card_name': '【招聘】前端招聘 (4pt)',
#   'card_id': '5ce10e7332ccf822175ecc12',
#   'member_id': '5ad8c41afae1085dac4eb40b',
#   'member_name': 'chenxi',
#   'plan_hours': 0,
#   'actual_hours': 8.0,
#   'description': 'https://www.yuque.com/covenantsql/vmodzd/qtwkiw\n题目 & 答案\n\nhttps://www.yuque.com/covenantsql/vmodzd/bqpkyw\n反馈\n'},
#  {'card_type': 'CQL8',
#   'card_name': '【CQL8】onboarding 开发 (8pt)',
#   'card_id': '5ce10ef9cf9e5a6025397d0a',
#   'member_id': '5ad8c41afae1085dac4eb40b',
#   'member_name': 'chenxi',
#   'plan_hours': 0,
#   'actual_hours': 16.0,
#   'description': 'UI 切面已经 OK，需要联调'},
#  {'card_type': 'CQL8',
#   'card_name': '【CQL8】用户 onboarding 流程 & 线框设计 (4pt)',
#   'card_id': '5ce10a7aa5fdd9333fd16a81',
#   'member_id': '5ad8c41afae1085dac4eb40b',
#   'member_name': 'chenxi',
#   'plan_hours': 0,
#   'actual_hours': 8.0,
#   'description': '产出线框图\nhttps://www.yuque.com/covenantsql/xsx66o/awbaih'},
#  {'card_type': 'CQL6',
#   'card_name': '【CQL6】更新官网 https://covenantsql.io/#blog 的《CovenantSQL 从零使用指南》（0.5pt）',
#   'card_id': '5cce7c307d01776552dd45ed',
#   'member_id': '5ad8c41afae1085dac4eb40b',
#   'member_name': 'chenxi',
#   'plan_hours': 0,
#   'actual_hours': 1.0,
#   'description': '跳转到 developer'},
#  {'card_type': 'CQL7',
#   'card_name': '【CQL7】Javascript 端到端加密支持 (2pt)',
#   'card_id': '5ce1f4f88573903d017ee57f',
#   'member_id': '504de163ee6286b550045e04',
#   'member_name': 'Qi Xiao',
#   'plan_hours': 0,
#   'actual_hours': 4.0,
#   'description': '估计用这几个就行：\nhttps://github.com/ricmoo/aes-js\nhttps://github.com/brightcove/pkcs7'},
#  {'card_type': 'CQL8',
#   'card_name': '【CQL8】对一下开发者项目管理部分功能的 API （0pt）(2pt)',
#   'card_id': '5ce1f1d847e39c167f46a438',
#   'member_id': '504de163ee6286b550045e04',
#   'member_name': 'Qi Xiao',
#   'plan_hours': 0.0,
#   'actual_hours': 4.0,
#   'description': ''},
#  {'card_type': 'CQL8',
#   'card_name': '【CQL8】firebase 化 —— oauth 部分（4pt）',
#   'card_id': '5cd8257a288b88644a6e424d',
#   'member_id': '504de163ee6286b550045e04',
#   'member_name': 'Qi Xiao',
#   'plan_hours': 0,
#   'actual_hours': 8.0,
#   'description': ''},
#  {'card_type': '招聘',
#   'card_name': '【招聘】面试 陶功维 (0.5pt)',
#   'card_id': '5cea9468d78282109d7c14f6',
#   'member_id': '504de163ee6286b550045e04',
#   'member_name': 'Qi Xiao',
#   'plan_hours': 0,
#   'actual_hours': 1.0,
#   'description': ''},
#  {'card_type': '招聘',
#   'card_name': '【招聘】面试 程双全 (0.5pt)',
#   'card_id': '5cea9474a0d9d88a684dce73',
#   'member_id': '504de163ee6286b550045e04',
#   'member_name': 'Qi Xiao',
#   'plan_hours': 0,
#   'actual_hours': 1.0,
#   'description': ''},
#  {'card_type': 'CQL8',
#   'card_name': '【CQL8】firebase 化 —— 迁移toD 的管理功能 (4pt) (8pt)',
#   'card_id': '5cd82907dc6cea4ed555aa4e',
#   'member_id': '504de163ee6286b550045e04',
#   'member_name': 'Qi Xiao',
#   'plan_hours': 8.0,
#   'actual_hours': 16.0,
#   'description': '支持托管 key 下 cql 中已经暴露的各种对 db 和账户的管理功能，转用 oauth 后作为 api 提供给前端使用 \n1. 领 testnet token\n2. db 创建/充值/CRUD 操作\n3. 查看账户余额、DB 余额、创建的 DB 等信息'},
#  {'card_type': None,
#   'card_name': '智能门锁演示程序 (4pt)',
#   'card_id': '5ce0e2edcd7c708429813ad9',
#   'member_id': '5293028f22779c60010068fc',
#   'member_name': '刘志腾',
#   'plan_hours': 0,
#   'actual_hours': 8.0,
#   'description': ''},
#  {'card_type': None,
#   'card_name': '调研 golang 生成 shared 库 (2pt)',
#   'card_id': '5ce359c60a8f3083df1d1651',
#   'member_id': '5293028f22779c60010068fc',
#   'member_name': '刘志腾',
#   'plan_hours': 0,
#   'actual_hours': 4.0,
#   'description': '#AC：\n\n如果没问题，提供一个在 c/c++ 中调用的示例代码'},
#  {'card_type': 'CQL3',
#   'card_name': '【CQL3】测试区块同步基线数据，确定每个量级的数据量的同步延迟情况和内存占用 (2pt)',
#   'card_id': '5ce4a4201d69d16ae44f08fe',
#   'member_id': '5293028f22779c60010068fc',
#   'member_name': '刘志腾',
#   'plan_hours': 0,
#   'actual_hours': 4.0,
#   'description': ''},
#  {'card_type': 'BUG',
#   'card_name': '【BUG】imx 发布版本中发现的一处访问越界 (4pt)',
#   'card_id': '5ce53f616ac57235965f0247',
#   'member_id': '5293028f22779c60010068fc',
#   'member_name': '刘志腾',
#   'plan_hours': 0,
#   'actual_hours': 8.0,
#   'description': ''},
#  {'card_type': 'CQL3',
#   'card_name': '【CQL3】最终一致性稳定性测试爆内存 (4pt)',
#   'card_id': '5cdd2c231d10b97f92566886',
#   'member_id': '5293028f22779c60010068fc',
#   'member_name': '刘志腾',
#   'plan_hours': 0,
#   'actual_hours': 8.0,
#   'description': ''},
#  {'card_type': None,
#   'card_name': '智能门锁方案 ppt (1pt)',
#   'card_id': '5ce0e2de622da70d57884100',
#   'member_id': '5293028f22779c60010068fc',
#   'member_name': '刘志腾',
#   'plan_hours': 0,
#   'actual_hours': 2.0,
#   'description': ''},
#  {'card_type': 'CQL5',
#   'card_name': '【CQL5】cql交互优化(2pt)',
#   'card_id': '5cd82b15e9753a080f1d1ab0',
#   'member_id': '53cf67682b7646ba72578805',
#   'member_name': 'laodouya',
#   'plan_hours': 0,
#   'actual_hours': 4.0,
#   'description': ''},
#  {'card_type': 'CQL1',
#   'card_name': '【CQL1】宕机自动恢复测试(6pt)(8pt)',
#   'card_id': '5caa01f985a7db24b7b4f80e',
#   'member_id': '53cf67682b7646ba72578805',
#   'member_name': 'laodouya',
#   'plan_hours': 12.0,
#   'actual_hours': 16.0,
#   'description': '# AC\n提供一个可以用命令随机杀一个leader/follower节点的docker测试模式'},
#  {'card_type': 'bug',
#   'card_name': '【bug】cql grant设置为void会出错(1pt)',
#   'card_id': '5cdcbef13976978d0427e312',
#   'member_id': '53cf67682b7646ba72578805',
#   'member_name': 'laodouya',
#   'plan_hours': 0,
#   'actual_hours': 2.0,
#   'description': '    1、数据库管理-> 数据库权限管理->\n        增加权限成功，吊销权限时报错\n\n        Yws-MacBook-Pro:~ xueyuwei$ cql grant \'{"chain":"a875020067c34c0d080c1fde7652c20c8ccea24ec35ead3988f78a777ac888c0", "user":"9e1618775cceeb19f110e04fbc6c5bca6c8e4e9b116e193a42fe69bf602e7bcd", "perm": "Void"}\'\n        INFO[0000] cql build: cql v0.5.0 darwin amd64 go1.12.4\n        Enter master key(press Enter for default: ""):\n\n        INFO[0001] init config success                           path=/Users/xueyuwei/.cql/config.yaml\n        ERRO[0001] update permission failed: invalid permission description\n'},
#  {'card_type': 'CQL5',
#   'card_name': '【CQL5】文档流程问题修改(6pt)(4pt)',
#   'card_id': '5cdcc52fb1169855b7165e4d',
#   'member_id': '53cf67682b7646ba72578805',
#   'member_name': 'laodouya',
#   'plan_hours': 12.0,
#   'actual_hours': 8.0,
#   'description': 'http://developers.covenantsql.io\n\n一、页面元素问题\n\n  1、数据库管理-> sql白名单->\n        去掉白名单限制：cql grant \'\n        {\n            "chain": "4bc27a06ae52a7b8b1747f3808dda786ddd188627bafe8e34a332626e7232ba5",\n            "user": "011f72fea9efa1a49a6663d66e514a34e45e426524c13335cf20bec1b47d10d6",\n            "perm": {\n                "patterns": nil,\n                "role": "Read,Write"\n            }\n        }\n        \'\n\n        json串："patterns": nil, 应为null\nDONE\n\n    2、快速开始-> 创建数据库->\n        cql create -config=~/.cql/testnet-conf/config.yaml -no-password \\ \n        -wait-tx-confirm \'{"node":1}\'\n\n        执行copy后的命令时：“\\” 以后会被忽略\n无法复现\n\n    3、快速开始-> 访问数据库-> \n        1.执行copy后的命令时：“\\” 以后会被忽略\n        2.连接失败时依然进入到客户端命令模式\n无法复现\n\n    4、简介-> 账号私钥和配置文件->\n        使用 Docker 一键部署的网络）链接地址不对\nDone\n\n    5、账号管理-> 创建新账号->\n        目前默认生成的配置文件指向测试网，还需要提供生成指向 Docker 一键部署网络的配置方法。\n\n        提供生成指向 Docker 一键部署网络的配置方法 没有链接\nDone\n\n    6、账号管理-> 子命令 generate 完整参数->\n        通用参数部分参考 子命令通用参数，以下介绍其他子命令时不再另外说明。\n\n        子命令通用参数 链接地址不对\nDone\n\n\n    8、钱包管理-> 向其他账号转账->\n        从 TestNet 获得代币或 Docker 一键部署的网络获得代币后，可以使用 transfer 命令来向其他账号转账。转账操作使用 json 格式的转账信息作为参数，例如：\n\n        Docker 一键部署 链接地址不对\nDone\n\n\n\n二、客户端命令行交互问题\n\n\n    1、访问数据库-> 访问数据库->\n        新授权用户（公共用户）连接数据库超时\nDone\n\n三、其他\n\n\ncovenantsql.io\n\n页面 https://covenantsql.io/blog/quickstart-zh?lang=en\n1. Documents of CLI and SDK\n    CLI Document: CLI README.md   连接地址404\n已经失效'},
#  {'card_type': 'bug',
#   'card_name': '【bug】Docker compose 启动的 adapter 默认不开 ssl（0.5pt）',
#   'card_id': '5ce3faa638d34860fe69ff72',
#   'member_id': '53cf67682b7646ba72578805',
#   'member_name': 'laodouya',
#   'plan_hours': 0,
#   'actual_hours': 1.0,
#   'description': ''},
#  {'card_type': 'bug',
#   'card_name': '【bug】CQL 命令问题(4pt)(3pt)',
#   'card_id': '5cde645a8e47274d4871cfc9',
#   'member_id': '53cf67682b7646ba72578805',
#   'member_name': 'laodouya',
#   'plan_hours': 8.0,
#   'actual_hours': 6.0,
#   'description': ''},
#  {'card_type': '杂事',
#   'card_name': '【杂事】熟悉区块链基本概念(3pt)',
#   'card_id': '5cce6a1f9cfd331686fe4fdd',
#   'member_id': None,
#   'member_name': None,
#   'plan_hours': 0,
#   'actual_hours': 6.0,
#   'description': '#AC\n回答出以下问题：\n1. 比特币的几次出块可以保证交易稳定，此时交易确认被推翻的概率是多少？\n2. EOS每个区块的大致存储结构是什么？'},
#  {'card_type': 'CQL5',
#   'card_name': '【CQL5】增加cql单元测试覆盖度(4pt)',
#   'card_id': '5cce763f768e6033e7f2ed1c',
#   'member_id': None,
#   'member_name': None,
#   'plan_hours': 0,
#   'actual_hours': 8.0,
#   'description': '#AC\ncql目录单元测试覆盖率达到70%\n'},
#  {'card_type': 'CQL1',
#   'card_name': '【CQL1】Offline Research works（4pt）',
#   'card_id': '5ce78dde8d9fe0541e953b94',
#   'member_id': '5ac48271f7bb0e571a84c7d8',
#   'member_name': 'Pengcheng Wang',
#   'plan_hours': 0,
#   'actual_hours': 8.0,
#   'description': 'http://seafile.morenodes.com:11103/f/64f4bbab5846441ca314/'},
#  {'card_type': 'bug',
#   'card_name': '【bug】修复 java driver 的一些 bug，重命名 Java/Python Driver （1pt）',
#   'card_id': '5ce3e0b7d1f84a181171d60e',
#   'member_id': '5ac48271f7bb0e571a84c7d8',
#   'member_name': 'Pengcheng Wang',
#   'plan_hours': 0,
#   'actual_hours': 2.0,
#   'description': ''},
#  {'card_type': 'CQL7',
#   'card_name': '【CQL7】端到端加密函数(6pt)',
#   'card_id': '5cd825b3d3e5592790ff3c3c',
#   'member_id': '5ac48271f7bb0e571a84c7d8',
#   'member_name': 'Pengcheng Wang',
#   'plan_hours': 0,
#   'actual_hours': 12.0,
#   'description': ' (aes128, pkcs#7 padding) '},
#  {'card_type': 'CQL5',
#   'card_name': '【CQL5】py预留时间（4pt）',
#   'card_id': '5ce10b7fbf2ec844cd9c62c7',
#   'member_id': '5ac48271f7bb0e571a84c7d8',
#   'member_name': 'Pengcheng Wang',
#   'plan_hours': 0,
#   'actual_hours': 8.0,
#   'description': ''}]

# %%
board_members = fetch_members_by_board()


df_list = []

for item in period_list("Done[20190215]")[7:]:
    
    new_workinfo = get_cards_info(item, board_members)
    
    df_new = pd.DataFrame(new_workinfo)
    df_new.to_csv('CQL_{}.csv'.format(item))

# %%
files = os.listdir('/Users/lichenxi/venv/CovenantSQL/Trello Analyzer')

# %%
fn = files[0]
df = pd.read_csv(os.path.join('/Users/lichenxi/venv/CovenantSQL/Trello Analyzer', fn))

# %%
dfs = []
for fn in files:
    try:
        df = pd.read_csv(os.path.join('/Users/lichenxi/venv/CovenantSQL/Trello Analyzer', fn))
        df.set_index("Unnamed: 0", inplace=True)
        dfs.append(df)
    except Exception as e:
        print('Error loading: ', fn)
        print(e)
# Out:
# Error loading:  work_hours_chart.png
# 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Error loading:  .ipynb_checkpoints
# Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.
# Error loading:  Trello_Analyzer_Original.ipynb
# Error tokenizing data. C error: Expected 1 fields in line 4, saw 2
#
# Error loading:  CQL_Statistic.ipynb
# Error tokenizing data. C error: Expected 1 fields in line 4, saw 2
#
# Error loading:  Trello_analyzer.ipynb
# Error tokenizing data. C error: Expected 1 fields in line 4, saw 2

# %%
result = pd.concat(dfs,join='outer')
# Out:
# /Users/lichenxi/venv/venv/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
result.to_csv("CQL_statistic.csv", encoding='utf_8_sig') # 防止中文乱码

# %%
# CQL 等应该变成 columns 
# raw 依旧是时间
# 单元格中是所花的时间

# %%
actual hours 是一个 list 包含了所有类型的工作时间

# %%
result.set_index("card_type")
# Out:
#        actual_hours                   card_id  \
# index
# 0               8.0  5cf77b9ab4d6ac7af78262e6
# 1               2.0  5cf7a6d73cac8c1b97344b2a
# 2               4.0  5ceab78e44229a35094feb1e
# 3               2.0  5cf63c740aeb5e560631f1f4
# 4               2.0  5cf1067c0541170cb9f84e98
# 5              12.0  5cf106f77ca01c4e505edbe6
# 6               2.0  5cf4f831a507d23952c18a2c
# 7               8.0  5cf3cd0007b5805a847db356
# 8               4.0  5cf3cd38d6763b29e5fde904
# 9               8.0  5cf3cd14fe049273a9960975
# 10              8.0  5cf3d4df0e74547b3bef4504
# 11              8.0  5cf3d4bc8fce0b844007a247
# 12              8.0  5cf3d4e2b7ad9e8888d651c0
# 13             16.0  5cf3d4e8cc40845e3a1f4529
# 14              4.0  5cf3d4e1d77ce68cba2a9957
# 15             12.0  5cf3c442182a1b4b0f862da9
# 16              2.0  5cf3c7636878275b1eaa30a0
# 17             16.0  5cf71a3106ead35ee480f4d4
# 18              2.0  5cf71965a688432a2304f38a
# 19             20.0  5cf3c8eb1fde82407ddd13e1
# 20              8.0  5cf3c95be79d7a6909a75609
# 0               2.0  5cc651ee8e2aaf31b3808364
# 1               6.0  5cc652622e8365189b33b746
# 2               2.0  5cc51a5ccea0b873147385d4
# 3               2.0  5cc6573d7e59588f64bdfd13
# 4               4.0  5cc7a4f17089324dbbe3f5b5
# 5              12.0  5cb3f9b4dceef262ece84d92
# 6               2.0  5ccd9036978bbf16656a4f9c
# 7               4.0  5cc7b597cc779e2f171e2744
# 8               8.0  5cbc777740fb4f26cc48c13d
# ...             ...                       ...
# 7              12.0  5c63b5fcb340143abb0c51ce
# 8               2.0  5c4131c06ea5165e21a57f13
# 0               8.0  5ce10e7332ccf822175ecc12
# 1              16.0  5ce10ef9cf9e5a6025397d0a
# 2               8.0  5ce10a7aa5fdd9333fd16a81
# 3               1.0  5cce7c307d01776552dd45ed
# 4               4.0  5ce1f4f88573903d017ee57f
# 5               4.0  5ce1f1d847e39c167f46a438
# 6               8.0  5cd8257a288b88644a6e424d
# 7               1.0  5cea9468d78282109d7c14f6
# 8               1.0  5cea9474a0d9d88a684dce73
# 9              16.0  5cd82907dc6cea4ed555aa4e
# 10              8.0  5ce0e2edcd7c708429813ad9
# 11              4.0  5ce359c60a8f3083df1d1651
# 12              4.0  5ce4a4201d69d16ae44f08fe
# 13              8.0  5ce53f616ac57235965f0247
# 14              8.0  5cdd2c231d10b97f92566886
# 15              2.0  5ce0e2de622da70d57884100
# 16              4.0  5cd82b15e9753a080f1d1ab0
# 17             16.0  5caa01f985a7db24b7b4f80e
# 18              2.0  5cdcbef13976978d0427e312
# 19              8.0  5cdcc52fb1169855b7165e4d
# 20              1.0  5ce3faa638d34860fe69ff72
# 21              6.0  5cde645a8e47274d4871cfc9
# 22              6.0  5cce6a1f9cfd331686fe4fdd
# 23              8.0  5cce763f768e6033e7f2ed1c
# 24              8.0  5ce78dde8d9fe0541e953b94
# 25              2.0  5ce3e0b7d1f84a181171d60e
# 26             12.0  5cd825b3d3e5592790ff3c3c
# 27              8.0  5ce10b7fbf2ec844cd9c62c7
#
#                                                card_name    card_type  \
# index
# 0                        【CQL8】Task 相关设计 & 实现 (3pt)(4pt)         CQL8
# 1             【CQL8】 Deploy 相关准备: stg-api， now.json（1pt）         CQL8
# 2                                   【CQL8】项目管理流程设计 (2pt)         CQL8
# 3                          【CQL8】 Menu 上 Wallet 入口 (1pt)         CQL8
# 4                                 【CQL8】get PTC 入口 (1pt)         CQL8
# 5      【CQL8】上传 wallet & set main wallet & 下载 & 删除 (3...         CQL8
# 6            【tokenmetric】add lang params & deploy (1pt)  tokenmetric
# 7                           【CQL10】Local File 结构设计 (4pt)        CQL10
# 8                              【CQL10】SDK API 列表文档 (2pt)        CQL10
# 9                                  【CQL10】同步合并逻辑设计 (4pt)        CQL10
# 10      【Demo】搭建环境，SecureGateway 还没有被使用过，预计会有很多联调问题（4pt）         Demo
# 11         【Demo】能够用不同的账号登陆系统看到有权限的 table 列，没有权限的打码（4pt）         Demo
# 12             【Demo】能够添加附件上传到 s3 并且记录 meta 信息到 cql（4pt）         Demo
# 13        【Demo】在每一行能展示相关的 SQL 在 Explorer 上的链接（4pt）（8pt）         Demo
# 14                         【Demo】对加密的列能够在前端用端到端加密解密（2pt）         Demo
# 15                     【CQL8】firebase 化 —— 开发者管理功能 (6pt)         CQL8
# 16               【CQL8】DBaaS 确定行级别权限控制 Rules 功能的设计 (1pt)         CQL8
# 17            【CQL8】firebase 化 —— 开发者管理功能，接续 (4pt) (8pt)         CQL8
# 18                                    【杂事】yuwei工作交接(1pt)           杂事
# 19                【CQL10】细化 IoT miner支持MQTT设计(8pt)(10pt)        CQL10
# 20                             【CQL10】miner实现MQTT协议(4pt)        CQL10
# 0                              【CQL5】Faucet API 调试 (1pt)         CQL5
# 1                               【CQL3】豆芽反馈的稳定性 bug (3pt)         CQL3
# 2                               【CQL5】Admin API 测试 (1pt)         CQL5
# 3                                   【CQL5】添加计费相关文档 (1pt)         CQL5
# 4                            【BUG】BP重启过程内存占用过大问题修复 (2pt)          BUG
# 5                               【CQL5】CQL 命令行工具问题列表(6pt)         CQL5
# 6                                   【杂事】总结工作，罗列新人计划(1pt)           杂事
# 7                                   【CQL5】CQL命令遗漏问题(2pt)         CQL5
# 8               【CQL5】定制一下对于 Serverless App 的权限管理方式（4pt）         CQL5
# ...                                                  ...          ...
# 7                       【测试网】 检查/修复子链的出块逻辑问题 (4pt) (6pt)          测试网
# 8               【优化】cql命令转账和创建数据库等操作是非同步操作，对使用带来的影响(1pt)           优化
# 0                                         【招聘】前端招聘 (4pt)           招聘
# 1                              【CQL8】onboarding 开发 (8pt)         CQL8
# 2                    【CQL8】用户 onboarding 流程 & 线框设计 (4pt)         CQL8
# 3      【CQL6】更新官网 https://covenantsql.io/#blog 的《Cove...         CQL6
# 4                         【CQL7】Javascript 端到端加密支持 (2pt)         CQL7
# 5                   【CQL8】对一下开发者项目管理部分功能的 API （0pt）(2pt)         CQL8
# 6                      【CQL8】firebase 化 —— oauth 部分（4pt）         CQL8
# 7                                     【招聘】面试 陶功维 (0.5pt)           招聘
# 8                                     【招聘】面试 程双全 (0.5pt)           招聘
# 9            【CQL8】firebase 化 —— 迁移toD 的管理功能 (4pt) (8pt)         CQL8
# 10                                        智能门锁演示程序 (4pt)          NaN
# 11                           调研 golang 生成 shared 库 (2pt)          NaN
# 12         【CQL3】测试区块同步基线数据，确定每个量级的数据量的同步延迟情况和内存占用 (2pt)         CQL3
# 13                         【BUG】imx 发布版本中发现的一处访问越界 (4pt)          BUG
# 14                             【CQL3】最终一致性稳定性测试爆内存 (4pt)         CQL3
# 15                                      智能门锁方案 ppt (1pt)          NaN
# 16                                    【CQL5】cql交互优化(2pt)         CQL5
# 17                              【CQL1】宕机自动恢复测试(6pt)(8pt)         CQL1
# 18                         【bug】cql grant设置为void会出错(1pt)          bug
# 19                              【CQL5】文档流程问题修改(6pt)(4pt)         CQL5
# 20       【bug】Docker compose 启动的 adapter 默认不开 ssl（0.5pt）          bug
# 21                               【bug】CQL 命令问题(4pt)(3pt)          bug
# 22                                    【杂事】熟悉区块链基本概念(3pt)           杂事
# 23                               【CQL5】增加cql单元测试覆盖度(4pt)         CQL5
# 24                     【CQL1】Offline Research works（4pt）         CQL1
# 25     【bug】修复 java driver 的一些 bug，重命名 Java/Python Dr...          bug
# 26                                    【CQL7】端到端加密函数(6pt)         CQL7
# 27                                     【CQL5】py预留时间（4pt）         CQL5
#
#                                              description label_id label_name  \
# index
# 0                                                    NaN      NaN        NaN
# 1      `stg-api.covenantsql.io/v3/admin/auth/authoriz...      NaN        NaN
# 2      产出线框图\n\nhttps://www.yuque.com/covenantsql/xsx...      NaN        NaN
# 3                                                    NaN      NaN        NaN
# 4                                                    NaN      NaN        NaN
# 5                                                    NaN      NaN        NaN
# 6                                                    NaN      NaN        NaN
# 7                                                    NaN      NaN        NaN
# 8                                                    NaN      NaN        NaN
# 9                                         # AC\n\n图例和伪代码      NaN        NaN
# 10                                                   NaN      NaN        NaN
# 11                                                   NaN      NaN        NaN
# 12                                                   NaN      NaN        NaN
# 13                                                   NaN      NaN        NaN
# 14                                                   NaN      NaN        NaN
# 15     定在周一和周二做完（6月3日~4日）\n接上周工作\n\n支持用户的管理和权限的配置\n对应...      NaN        NaN
# 16                                          暂时定在周二（6月4日）      NaN        NaN
# 17     定在周一和周二做完（6月3日~4日）\n接上周工作\n\n支持用户的管理和权限的配置\n对应...      NaN        NaN
# 18                                                   NaN      NaN        NaN
# 19                                                   NaN      NaN        NaN
# 20                                       broker存储接口实现和测试      NaN        NaN
# 0                          部署 chenxi 需要的 admin 的 api 和调试      NaN        NaN
# 1                                                    NaN      NaN        NaN
# 2                                                    NaN      NaN        NaN
# 3      # AC:\n\n添加 create db 时两个与计费相关的字段的解释，并解释计费机制，更...      NaN        NaN
# 4                                                    NaN      NaN        NaN
# 5                                                    NaN      NaN        NaN
# 6                                                    NaN      NaN        NaN
# 7                                                    NaN      NaN        NaN
# 8      http://seafile.morenodes.com:11103/lib/333ed25...      NaN        NaN
# ...                                                  ...      ...        ...
# 7           检查子链的出块逻辑问题\n貌似现在是 n 个 miner 的 db，就是 n 分钟一个块      NaN        NaN
# 8      对用户体验比较差，转账成功了对方查不到，创建成功了没法马上用。可以给一个查进度的方式，或者类...      NaN        NaN
# 0      https://www.yuque.com/covenantsql/vmodzd/qtwki...      NaN        NaN
# 1                                        UI 切面已经 OK，需要联调      NaN        NaN
# 2      产出线框图\nhttps://www.yuque.com/covenantsql/xsx66...      NaN        NaN
# 3                                          跳转到 developer      NaN        NaN
# 4      估计用这几个就行：\nhttps://github.com/ricmoo/aes-js\nh...      NaN        NaN
# 5                                                    NaN      NaN        NaN
# 6                                                    NaN      NaN        NaN
# 7                                                    NaN      NaN        NaN
# 8                                                    NaN      NaN        NaN
# 9      支持托管 key 下 cql 中已经暴露的各种对 db 和账户的管理功能，转用 oauth ...      NaN        NaN
# 10                                                   NaN      NaN        NaN
# 11                    #AC：\n\n如果没问题，提供一个在 c/c++ 中调用的示例代码      NaN        NaN
# 12                                                   NaN      NaN        NaN
# 13                                                   NaN      NaN        NaN
# 14                                                   NaN      NaN        NaN
# 15                                                   NaN      NaN        NaN
# 16                                                   NaN      NaN        NaN
# 17      # AC\n提供一个可以用命令随机杀一个leader/follower节点的docker测试模式      NaN        NaN
# 18         1、数据库管理-> 数据库权限管理->\n        增加权限成功，吊销权限时报...      NaN        NaN
# 19     http://developers.covenantsql.io\n\n一、页面元素问题\n...      NaN        NaN
# 20                                                   NaN      NaN        NaN
# 21                                                   NaN      NaN        NaN
# 22     #AC\n回答出以下问题：\n1. 比特币的几次出块可以保证交易稳定，此时交易确认被推翻的概...      NaN        NaN
# 23                              #AC\ncql目录单元测试覆盖率达到70%\n      NaN        NaN
# 24     http://seafile.morenodes.com:11103/f/64f4bbab5...      NaN        NaN
# 25                                                   NaN      NaN        NaN
# 26                             (aes128, pkcs#7 padding)       NaN        NaN
# 27                                                   NaN      NaN        NaN
#
#                       member_id     member_name  plan_hours
# index
# 0      5ad8c41afae1085dac4eb40b          chenxi         6.0
# 1      5ad8c41afae1085dac4eb40b          chenxi         0.0
# 2      5ad8c41afae1085dac4eb40b          chenxi         0.0
# 3      5ad8c41afae1085dac4eb40b          chenxi         0.0
# 4      5ad8c41afae1085dac4eb40b          chenxi         0.0
# 5      5ad8c41afae1085dac4eb40b          chenxi         6.0
# 6      5ad8c41afae1085dac4eb40b          chenxi         0.0
# 7      5293028f22779c60010068fc             刘志腾         0.0
# 8      5293028f22779c60010068fc             刘志腾         0.0
# 9      5293028f22779c60010068fc             刘志腾         0.0
# 10     5ac48271f7bb0e571a84c7d8  Pengcheng Wang         0.0
# 11     5ac48271f7bb0e571a84c7d8  Pengcheng Wang         0.0
# 12     5ac48271f7bb0e571a84c7d8  Pengcheng Wang         0.0
# 13     5ac48271f7bb0e571a84c7d8  Pengcheng Wang         8.0
# 14     5ac48271f7bb0e571a84c7d8  Pengcheng Wang         0.0
# 15     504de163ee6286b550045e04         Qi Xiao         0.0
# 16     504de163ee6286b550045e04         Qi Xiao         0.0
# 17     504de163ee6286b550045e04         Qi Xiao         8.0
# 18     53cf67682b7646ba72578805        laodouya         0.0
# 19     53cf67682b7646ba72578805        laodouya        16.0
# 20     53cf67682b7646ba72578805        laodouya         0.0
# 0      504de163ee6286b550045e04         Qi Xiao         0.0
# 1      504de163ee6286b550045e04         Qi Xiao         0.0
# 2      5ad8c41afae1085dac4eb40b          chenxi         0.0
# 3      5293028f22779c60010068fc             刘志腾         0.0
# 4      5293028f22779c60010068fc             刘志腾         0.0
# 5      5293028f22779c60010068fc             刘志腾         0.0
# 6      53cf67682b7646ba72578805        laodouya         0.0
# 7      53cf67682b7646ba72578805        laodouya         0.0
# 8      5ac48271f7bb0e571a84c7d8  Pengcheng Wang         0.0
# ...                         ...             ...         ...
# 7      504de163ee6286b550045e04         Qi Xiao         8.0
# 8      53cf67682b7646ba72578805        laodouya         0.0
# 0      5ad8c41afae1085dac4eb40b          chenxi         0.0
# 1      5ad8c41afae1085dac4eb40b          chenxi         0.0
# 2      5ad8c41afae1085dac4eb40b          chenxi         0.0
# 3      5ad8c41afae1085dac4eb40b          chenxi         0.0
# 4      504de163ee6286b550045e04         Qi Xiao         0.0
# 5      504de163ee6286b550045e04         Qi Xiao         0.0
# 6      504de163ee6286b550045e04         Qi Xiao         0.0
# 7      504de163ee6286b550045e04         Qi Xiao         0.0
# 8      504de163ee6286b550045e04         Qi Xiao         0.0
# 9      504de163ee6286b550045e04         Qi Xiao         8.0
# 10     5293028f22779c60010068fc             刘志腾         0.0
# 11     5293028f22779c60010068fc             刘志腾         0.0
# 12     5293028f22779c60010068fc             刘志腾         0.0
# 13     5293028f22779c60010068fc             刘志腾         0.0
# 14     5293028f22779c60010068fc             刘志腾         0.0
# 15     5293028f22779c60010068fc             刘志腾         0.0
# 16     53cf67682b7646ba72578805        laodouya         0.0
# 17     53cf67682b7646ba72578805        laodouya        12.0
# 18     53cf67682b7646ba72578805        laodouya         0.0
# 19     53cf67682b7646ba72578805        laodouya        12.0
# 20     53cf67682b7646ba72578805        laodouya         0.0
# 21     53cf67682b7646ba72578805        laodouya         8.0
# 22                          NaN             NaN         0.0
# 23                          NaN             NaN         0.0
# 24     5ac48271f7bb0e571a84c7d8  Pengcheng Wang         0.0
# 25     5ac48271f7bb0e571a84c7d8  Pengcheng Wang         0.0
# 26     5ac48271f7bb0e571a84c7d8  Pengcheng Wang         0.0
# 27     5ac48271f7bb0e571a84c7d8  Pengcheng Wang         0.0
#
# [374 rows x 10 columns]

# %%
result["actual_hours"][2]
# Out:
# pandas.core.series.Series
